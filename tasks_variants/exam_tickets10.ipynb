# %% [markdown]
# ## Завдання на практичну частину екзамену з дисципліни МІАЗ.
#
# ### Білет 10
#
# Створити прототип інформаційно-аналітичної системи для відображення інформації щодо використаних боєприпасів за останні 11 днів на основі наданого шаблону.
#
# 1. Створити базу даних exam_118, створити таблицю та заповнити її даними за допомогою sql-файлів з шаблону.
# 2. Backend на основі Python FastAPI (прописати URL для отримання даних, налаштувати параметри підключення до бази даних, та прописати оператор SELECT для вибірки необхідних полів:
#    date, location, [поле відповідно до завдання] as data_field)
# 3. Frontend на основі:
#    - HTML(додати місця розташування відповідних візуальних елементів)
#    - CSS (налаштувати кольорову схему)
#    - JavaScript (встановити базовий колір графіку та задати координати маркерів)
#
# 4. Кольорова схема має відповідати основному кольору Марун відповідно до [брендбуку ЗСУ](https://sprotyvg7.com.ua/wp-content/uploads/2024/06/1_%D0%9A%D0%95%D0%A0-%D0%97-%D0%92%D0%98%D0%9A-%D0%93%D0%A0-%D0%A1%D0%A2%D0%98%D0%9B%D0%AE-%D0%A3-%D0%92%D0%86%D0%97-%D0%9A%D0%9E%D0%9C-%D0%97%D0%A1%D0%A3.pdf).
# 5. Координати маркерів на інтерактивній карті:
#      A: [50.9607, 34.7427]
#      B: [48.4454, 35.0654]
#      C: [46.6280, 32.6612]
# 6. Запустити backend (uvicorn main:app --reload) та frontend (live server) частини інформаційно-аналітичної системи.
# 7. Надати роботу на перевірку.
